# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans

# %%
def discrimination(data, target, sens, expl, max_corr=.1):
    # target
    # sens: sensitive attribute
    # expl: explanatory attribute(s), str or list
    group_priv = data[data[sens]==2]
    group_prot = data[data[sens]==1]
    n_priv = group_priv.shape[0]
    n_prot = group_prot.shape[0]
    
    D_all = np.sum(group_priv[target]==1)/n_priv - np.sum(group_prot[target] == 1)/n_prot
    print('Total discrimination: %.2f' % D_all)
    
    # multiple explanatory attributes
    if isinstance(expl, list):
#         high_corr = list(data.columns[np.abs(data.corr()[sens].sort_values()) > max_corr])
        high_corr = []
        for e in expl: 
            if e in high_corr: 
                print(e, 'is highly correlated with', sens)
        expl = [e for e in expl if e not in high_corr]
        data_expl = pd.Series(KMeans(n_clusters=6).fit(data[expl]).labels_)
    else:
        data_expl = data[expl]
    
    data_expl_priv = data_expl[data[sens]==2]
    data_expl_prot = data_expl[data[sens]==1]
        
    expl_values = data_expl.unique()
    D_expl = 0 
    
    for e_i in expl_values:
        P_star = (np.sum((group_priv[target]==1) & (data_expl_priv == e_i))/n_priv + 
                  np.sum((group_prot[target]==1) & (data_expl_prot == e_i))/n_prot)/2
        D_expl += (np.sum(data_expl_priv == e_i)/n_priv - np.sum(data_expl_prot == e_i)/n_prot) * P_star
        
    print('Discrimination explainable by %s: %.2f' % (', '.join(expl), D_expl))
    
    D_illegal = D_all - D_expl
    print('Unexplainable discrimination: %.2f' % D_illegal)
    
    return (D_all, D_expl, D_illegal)

# %% [markdown]
# Import data and ignore native workers

# %%
credit_df = pd.read_csv('./resampled_nation.csv')
credit_df.columns

legal = credit_df.columns[ [1, 3, 5, 6, 8, 10, 12, 14, 16 ] ]
maybe = credit_df.columns[ [1, 2, 3, 4, 5, 6, 8, 10, 11, 12, 14, 15, 16, 17 ] ]

male_idx = (credit_df['Sex & Marital Status']==1) | (credit_df['Sex & Marital Status']==3) | \
                 (credit_df['Sex & Marital Status']==4)
female_idx = (credit_df['Sex & Marital Status']==2) | (credit_df['Sex & Marital Status']==5)
native_idx = (credit_df['Foreign Worker']==2)
foreign_idx = (credit_df['Foreign Worker']==1)

# insert a column of gender, 1 female, 2 female
credit_df.insert(loc=len(credit_df.columns), column='gender', value=1)
credit_df.loc[male_idx, 'gender'] = 2

# remove rows of native workers
credit_df = credit_df[foreign_idx]
credit_df = credit_df.reset_index(drop=True)

# check the original discrimination w.r.t. gender after removing native workers
discrimination(credit_df, 'Creditability', 'gender', list(legal))

credit_df.corr()
# Out:
# Total discrimination: 0.12
# Discrimination explainable by Account Balance, Payment Status of Previous Credit, Credit Amount, Value Savings/Stocks, Instalment per cent, Guarantors, Most valuable available asset, Concurrent Credits, No of Credits at this Bank: 0.04
# Unexplainable discrimination: 0.08
#                                    Creditability  Account Balance  \
# Creditability                           1.000000         0.305876
# Account Balance                         0.305876         1.000000
# Duration of Credit (month)             -0.356103        -0.116006
# Payment Status of Previous Credit       0.141212        -0.044355
# Purpose                                -0.142146        -0.024172
# Credit Amount                          -0.324871        -0.119262
# Value Savings/Stocks                    0.212737         0.288867
# Length of current employment           -0.049507         0.143971
# Instalment per cent                    -0.031011         0.083687
# Sex & Marital Status                    0.187233         0.121248
# Guarantors                             -0.038271        -0.237017
# Duration in Current address            -0.092593        -0.155970
# Most valuable available asset          -0.206193         0.096935
# Age (years)                             0.023524         0.075975
# Concurrent Credits                      0.176702         0.116866
# Type of apartment                       0.009309         0.022006
# No of Credits at this Bank              0.034464        -0.032084
# Occupation                             -0.236427        -0.032639
# No of dependents                        0.130624         0.046378
# Telephone                              -0.192890        -0.025749
# Foreign Worker                          0.232325        -0.082068
# gender                                  0.123399         0.124164
#
#                                    Duration of Credit (month)  \
# Creditability                                       -0.356103
# Account Balance                                     -0.116006
# Duration of Credit (month)                           1.000000
# Payment Status of Previous Credit                   -0.172924
# Purpose                                              0.358485
# Credit Amount                                        0.651721
# Value Savings/Stocks                                 0.005645
# Length of current employment                         0.083694
# Instalment per cent                                  0.071806
# Sex & Marital Status                                -0.192687
# Guarantors                                          -0.070440
# Duration in Current address                          0.070983
# Most valuable available asset                        0.370965
# Age (years)                                         -0.102406
# Concurrent Credits                                  -0.185463
# Type of apartment                                    0.176634
# No of Credits at this Bank                          -0.042907
# Occupation                                           0.330988
# No of dependents                                    -0.193504
# Telephone                                            0.301427
# Foreign Worker                                      -0.386479
# gender                                              -0.207753
#
#                                    Payment Status of Previous Credit  \
# Creditability                                               0.141212
# Account Balance                                            -0.044355
# Duration of Credit (month)                                 -0.172924
# Payment Status of Previous Credit                           1.000000
# Purpose                                                    -0.171950
# Credit Amount                                              -0.202143
# Value Savings/Stocks                                       -0.027384
# Length of current employment                                0.180951
# Instalment per cent                                         0.002058
# Sex & Marital Status                                        0.117104
# Guarantors                                                 -0.008775
# Duration in Current address                                 0.223642
# Most valuable available asset                              -0.178548
# Age (years)                                                 0.247101
# Concurrent Credits                                          0.243325
# Type of apartment                                           0.005506
# No of Credits at this Bank                                  0.536339
# Occupation                                                 -0.110400
# No of dependents                                            0.182660
# Telephone                                                   0.022065
# Foreign Worker                                              0.042953
# gender                                                      0.130734
#
#                                     Purpose  Credit Amount  \
# Creditability                     -0.142146      -0.324871
# Account Balance                   -0.024172      -0.119262
# Duration of Credit (month)         0.358485       0.651721
# Payment Status of Previous Credit -0.171950      -0.202143
# Purpose                            1.000000       0.294799
# Credit Amount                      0.294799       1.000000
# Value Savings/Stocks              -0.066877       0.026366
# Length of current employment      -0.011180       0.059581
# Instalment per cent                0.069136      -0.331996
# Sex & Marital Status              -0.105845      -0.296957
# Guarantors                        -0.054620      -0.071441
# Duration in Current address       -0.011040       0.062958
# Most valuable available asset      0.110098       0.239611
# Age (years)                       -0.053939      -0.006282
# Concurrent Credits                -0.134510      -0.186377
# Type of apartment                  0.184029       0.116305
# No of Credits at this Bank         0.022992      -0.076812
# Occupation                         0.251789       0.408484
# No of dependents                  -0.170353      -0.121773
# Telephone                          0.223673       0.422815
# Foreign Worker                    -0.332328      -0.071254
# gender                            -0.173606      -0.194529
#
#                                    Value Savings/Stocks  \
# Creditability                                  0.212737
# Account Balance                                0.288867
# Duration of Credit (month)                     0.005645
# Payment Status of Previous Credit             -0.027384
# Purpose                                       -0.066877
# Credit Amount                                  0.026366
# Value Savings/Stocks                           1.000000
# Length of current employment                   0.072897
# Instalment per cent                           -0.021828
# Sex & Marital Status                           0.037914
# Guarantors                                    -0.126527
# Duration in Current address                   -0.075357
# Most valuable available asset                  0.061505
# Age (years)                                   -0.002578
# Concurrent Credits                             0.133522
# Type of apartment                              0.025450
# No of Credits at this Bank                    -0.095014
# Occupation                                    -0.044503
# No of dependents                              -0.069238
# Telephone                                      0.015992
# Foreign Worker                                 0.033130
# gender                                        -0.010618
#
#                                    Length of current employment  \
# Creditability                                         -0.049507
# Account Balance                                        0.143971
# Duration of Credit (month)                             0.083694
# Payment Status of Previous Credit                      0.180951
# Purpose                                               -0.011180
# Credit Amount                                          0.059581
# Value Savings/Stocks                                   0.072897
# Length of current employment                           1.000000
# Instalment per cent                                    0.074041
# Sex & Marital Status                                  -0.057036
# Guarantors                                             0.071367
# Duration in Current address                            0.369288
# Most valuable available asset                          0.103137
# Age (years)                                            0.323616
# Concurrent Credits                                     0.068742
# Type of apartment                                      0.079749
# No of Credits at this Bank                             0.070239
# Occupation                                             0.142414
# No of dependents                                       0.029483
# Telephone                                              0.129028
# Foreign Worker                                        -0.066489
# gender                                                 0.143591
#
#                                    Instalment per cent  Sex & Marital Status  \
# Creditability                                -0.031011              0.187233
# Account Balance                               0.083687              0.121248
# Duration of Credit (month)                    0.071806             -0.192687
# Payment Status of Previous Credit             0.002058              0.117104
# Purpose                                       0.069136             -0.105845
# Credit Amount                                -0.331996             -0.296957
# Value Savings/Stocks                         -0.021828              0.037914
# Length of current employment                  0.074041             -0.057036
# Instalment per cent                           1.000000              0.193468
# Sex & Marital Status                          0.193468              1.000000
# Guarantors                                   -0.066731              0.060178
# Duration in Current address                  -0.076158             -0.176200
# Most valuable available asset                 0.167463             -0.126155
# Age (years)                                  -0.003395             -0.040897
# Concurrent Credits                           -0.070360              0.039128
# Type of apartment                             0.117943              0.024166
# No of Credits at this Bank                    0.025049              0.086082
# Occupation                                    0.067896             -0.242347
# No of dependents                             -0.185256              0.116797
# Telephone                                    -0.061908             -0.217303
# Foreign Worker                               -0.236161              0.196077
# gender                                        0.132040              0.642956
#
#                                      ...     Most valuable available asset  \
# Creditability                        ...                         -0.206193
# Account Balance                      ...                          0.096935
# Duration of Credit (month)           ...                          0.370965
# Payment Status of Previous Credit    ...                         -0.178548
# Purpose                              ...                          0.110098
# Credit Amount                        ...                          0.239611
# Value Savings/Stocks                 ...                          0.061505
# Length of current employment         ...                          0.103137
# Instalment per cent                  ...                          0.167463
# Sex & Marital Status                 ...                         -0.126155
# Guarantors                           ...                         -0.176323
# Duration in Current address          ...                          0.063250
# Most valuable available asset        ...                          1.000000
# Age (years)                          ...                          0.024641
# Concurrent Credits                   ...                         -0.261645
# Type of apartment                    ...                          0.172379
# No of Credits at this Bank           ...                         -0.040359
# Occupation                           ...                          0.342252
# No of dependents                     ...                         -0.175691
# Telephone                            ...                          0.252882
# Foreign Worker                       ...                         -0.352564
# gender                               ...                         -0.102105
#
#                                    Age (years)  Concurrent Credits  \
# Creditability                         0.023524            0.176702
# Account Balance                       0.075975            0.116866
# Duration of Credit (month)           -0.102406           -0.185463
# Payment Status of Previous Credit     0.247101            0.243325
# Purpose                              -0.053939           -0.134510
# Credit Amount                        -0.006282           -0.186377
# Value Savings/Stocks                 -0.002578            0.133522
# Length of current employment          0.323616            0.068742
# Instalment per cent                  -0.003395           -0.070360
# Sex & Marital Status                 -0.040897            0.039128
# Guarantors                           -0.092104           -0.083877
# Duration in Current address           0.213182            0.036945
# Most valuable available asset         0.024641           -0.261645
# Age (years)                           1.000000            0.065608
# Concurrent Credits                    0.065608            1.000000
# Type of apartment                     0.175564            0.050993
# No of Credits at this Bank            0.233216           -0.068373
# Occupation                           -0.033335           -0.144559
# No of dependents                      0.181055            0.112141
# Telephone                             0.136677           -0.032934
# Foreign Worker                        0.022118            0.009547
# gender                                0.206628            0.113482
#
#                                    Type of apartment  \
# Creditability                               0.009309
# Account Balance                             0.022006
# Duration of Credit (month)                  0.176634
# Payment Status of Previous Credit           0.005506
# Purpose                                     0.184029
# Credit Amount                               0.116305
# Value Savings/Stocks                        0.025450
# Length of current employment                0.079749
# Instalment per cent                         0.117943
# Sex & Marital Status                        0.024166
# Guarantors                                 -0.233759
# Duration in Current address                 0.028199
# Most valuable available asset               0.172379
# Age (years)                                 0.175564
# Concurrent Credits                          0.050993
# Type of apartment                           1.000000
# No of Credits at this Bank                  0.049352
# Occupation                                  0.097824
# No of dependents                           -0.025467
# Telephone                                   0.125857
# Foreign Worker                             -0.252082
# gender                                      0.102899
#
#                                    No of Credits at this Bank  Occupation  \
# Creditability                                        0.034464   -0.236427
# Account Balance                                     -0.032084   -0.032639
# Duration of Credit (month)                          -0.042907    0.330988
# Payment Status of Previous Credit                    0.536339   -0.110400
# Purpose                                              0.022992    0.251789
# Credit Amount                                       -0.076812    0.408484
# Value Savings/Stocks                                -0.095014   -0.044503
# Length of current employment                         0.070239    0.142414
# Instalment per cent                                  0.025049    0.067896
# Sex & Marital Status                                 0.086082   -0.242347
# Guarantors                                          -0.086177    0.055545
# Duration in Current address                          0.057265    0.069676
# Most valuable available asset                       -0.040359    0.342252
# Age (years)                                          0.233216   -0.033335
# Concurrent Credits                                  -0.068373   -0.144559
# Type of apartment                                    0.049352    0.097824
# No of Credits at this Bank                           1.000000   -0.071033
# Occupation                                          -0.071033    1.000000
# No of dependents                                     0.200576   -0.273931
# Telephone                                           -0.023860    0.487713
# Foreign Worker                                      -0.087615   -0.217396
# gender                                               0.083183   -0.137645
#
#                                    No of dependents  Telephone  \
# Creditability                              0.130624  -0.192890
# Account Balance                            0.046378  -0.025749
# Duration of Credit (month)                -0.193504   0.301427
# Payment Status of Previous Credit          0.182660   0.022065
# Purpose                                   -0.170353   0.223673
# Credit Amount                             -0.121773   0.422815
# Value Savings/Stocks                      -0.069238   0.015992
# Length of current employment               0.029483   0.129028
# Instalment per cent                       -0.185256  -0.061908
# Sex & Marital Status                       0.116797  -0.217303
# Guarantors                                -0.017371  -0.138251
# Duration in Current address                0.037354   0.177627
# Most valuable available asset             -0.175691   0.252882
# Age (years)                                0.181055   0.136677
# Concurrent Credits                         0.112141  -0.032934
# Type of apartment                         -0.025467   0.125857
# No of Credits at this Bank                 0.200576  -0.023860
# Occupation                                -0.273931   0.487713
# No of dependents                           1.000000  -0.192113
# Telephone                                 -0.192113   1.000000
# Foreign Worker                             0.161501  -0.209176
# gender                                     0.243083  -0.125592
#
#                                    Foreign Worker    gender
# Creditability                            0.232325  0.123399
# Account Balance                         -0.082068  0.124164
# Duration of Credit (month)              -0.386479 -0.207753
# Payment Status of Previous Credit        0.042953  0.130734
# Purpose                                 -0.332328 -0.173606
# Credit Amount                           -0.071254 -0.194529
# Value Savings/Stocks                     0.033130 -0.010618
# Length of current employment            -0.066489  0.143591
# Instalment per cent                     -0.236161  0.132040
# Sex & Marital Status                     0.196077  0.642956
# Guarantors                               0.274392  0.028505
# Duration in Current address             -0.115599 -0.087039
# Most valuable available asset           -0.352564 -0.102105
# Age (years)                              0.022118  0.206628
# Concurrent Credits                       0.009547  0.113482
# Type of apartment                       -0.252082  0.102899
# No of Credits at this Bank              -0.087615  0.083183
# Occupation                              -0.217396 -0.137645
# No of dependents                         0.161501  0.243083
# Telephone                               -0.209176 -0.125592
# Foreign Worker                           1.000000  0.211645
# gender                                   0.211645  1.000000
#
# [22 rows x 22 columns]

# %%
Find the correct
